# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro-Lucas-Vieira/Aurora-AI/blob/main/test_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# AURORA AI
# Interface desenvolvida com Streamlit
# ============================================================

# Biblioteca do Streamlit
import streamlit as st

# Importa a função que conversa com a IA
from chatbot import responder


# ============================================================
# CONFIGURAÇÃO DA PÁGINA
# ============================================================

st.set_page_config(
    page_title="AURORA AI",
    page_icon="🤖",  # Substituído favicon por emoji
    layout="wide",
    initial_sidebar_state="expanded"
)


# ============================================================
# CSS DA APLICAÇÃO
# ============================================================

st.markdown("""
<style>
.block-container{
    max-width:1100px;
    padding-top:2rem;
}

[data-testid="stHeader"]{
    background:transparent;
}

section[data-testid="stSidebar"]{
    background:#1A102C;
}

.sidebar-title{
    font-size:1.6rem;
    font-weight:bold;
    color:white;
}

.small{
    color:#B9B5C8;
}

.stButton>button{
    width:100%;
    border:none;
    border-radius:12px;
    background:#7C3AED;
    color:white;
    font-weight:bold;
}

.stButton>button:hover{
    background:#8B5CF6;
}
</style>
""", unsafe_allow_html=True)
